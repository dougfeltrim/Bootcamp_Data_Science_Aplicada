# %% [markdown]
# <a href="https://colab.research.google.com/github/dougfeltrim/Bootcamp_Data_Science_Aplicada/blob/main/Bootcamp_Data_Science_Aplicada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A182510189_28_143_208.csv", engine='python', encoding="utf-8", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
dados.head()
# Out:
#   Unidade da Federação     2008/Jan  ...     2021/Mar         Total
# 0          11 Rondônia   1388528.39  ...  11023309.47  9.964113e+08
# 1              12 Acre    902416.00  ...   4077045.92  4.500485e+08
# 2          13 Amazonas   4735529.42  ...  22032176.22  1.917248e+09
# 3           14 Roraima    657889.53  ...   3985530.08  3.288770e+08
# 4              15 Pará  18864744.11  ...  33276392.89  4.705309e+09
#
# [5 rows x 161 columns]

# %%
dados.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Dez    5.337776e+07
# 2021/Jan    5.607375e+07
# 2021/Fev    5.557823e+07
# 2021/Mar    6.250230e+07
# Total       6.388213e+09
# Length: 159, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 161 entries, Unidade da Federação to Total
# dtypes: float64(159), object(2)
# memory usage: 34.1+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Dez     53377763.15
# 2021/Jan     56073748.02
# 2021/Fev     55578233.31
# 2021/Mar     62502301.42
# Total      6388213338.48
# Length: 159, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 27800320.306666665

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x='Unidade da Federação' , y='2008/Ago', kind='bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Custo Hospitalar no Brasil em Agosto de 2008")

plt.show()

# %%
ax = dados.plot(x='Unidade da Federação' , y='2021/Mar', kind='bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Custo Hospitalar no Brasil em Março de 2021")

plt.show()

# %%
diferenca = dados['2021/Mar'].mean() - dados['2008/Ago'].mean()
print('%.2f' %  diferenca)
# Out:
# 34701981.11

# %%
dados[['2008/Mar','2021/Mar']]
# Out:
#        2008/Mar     2021/Mar
# 0    1541682.52  11023309.47
# 1    1794028.48   4077045.92
# 2    8196635.49  22032176.22
# 3     718688.03   3985530.08
# 4   21937342.70  33276392.89
# 5     974651.24   3188210.98
# 6    6205612.60   1357751.33
# 7   13985142.36  39663677.48
# 8   10298372.45  20018325.75
# 9   28724625.75  62079618.54
# 10  10352238.59  23306498.68
# 11  12053643.87  25750897.89
# 12  29991302.71  83870992.73
# 13   8408336.22  22118639.05
# 14   5051473.61  13321494.41
# 15  34181483.52  98746333.07
# 16  79231336.95 200471045.07
# 17  10249595.97  45490499.45
# 18  44567062.94 106837295.81
# 19 156087269.23 392946147.42
# 20  53801318.85 140264608.52
# 21  26743524.89  81376630.57
# 22  51547794.07 130155185.16
# 23   8423933.19  25168195.34
# 24   7886243.14  19611032.61
# 25  21442515.75  45592686.49
# 26   9647203.26  31831917.45

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, 'Unidade da Federação')

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação    2008/Jan  ...    2021/Mar         Total
# 0          11 Rondônia  1388528.39  ... 11023309.47  996411254.68
# 1              12 Acre   902416.00  ...  4077045.92  450048530.47
# 2          13 Amazonas  4735529.42  ... 22032176.22 1917247936.05
# 3           14 Roraima   657889.53  ...  3985530.08  328876965.09
# 4              15 Pará 18864744.11  ... 33276392.89 4705309002.29
#
# [5 rows x 160 columns]

# %%
usaveis = usaveis.set_index(['Unidade da Federação'])

usaveis
# Out:
#                           2008/Jan     2008/Fev  ...     2021/Mar          Total
# Unidade da Federação                             ...
# 11 Rondônia             1388528.39   2931283.42  ...  11023309.47   996411254.68
# 12 Acre                  902416.00   1497206.26  ...   4077045.92   450048530.47
# 13 Amazonas             4735529.42   7118990.57  ...  22032176.22  1917247936.05
# 14 Roraima               657889.53    777939.31  ...   3985530.08   328876965.09
# 15 Pará                18864744.11  19553758.20  ...  33276392.89  4705309002.29
# 16 Amapá                1120973.34   1268740.33  ...   3188210.98   309860092.59
# 17 Tocantins            3441592.69   4985688.85  ...   1357751.33  1020028272.64
# 21 Maranhão            10723506.39  13559679.41  ...  39663677.48  3871069498.04
# 22 Piauí                7985142.43  10079928.25  ...  20018325.75  2280888802.74
# 23 Ceará               15539821.90  25735101.55  ...  62079618.54  6591836650.18
# 24 Rio Grande do Norte  5947814.08   9509755.83  ...  23306498.68  2660122027.15
# 25 Paraíba             10723002.45  11386274.47  ...  25750897.89  2614919044.63
# 26 Pernambuco          14393949.89  24181400.95  ...  83870992.73  8581189975.91
# 27 Alagoas              6243726.32   8376622.16  ...  22118639.05  2236415402.51
# 28 Sergipe              2780750.11   3676483.16  ...  13321494.41  1215853015.00
# 29 Bahia               21211522.47  28189304.95  ...  98746333.07  9791541570.52
# 31 Minas Gerais        45671659.76  70194037.10  ... 200471045.07 20418737536.66
# 32 Espírito Santo       5456723.98   9102212.86  ...  45490499.45  3405850698.58
# 33 Rio de Janeiro      23025258.52  28394310.93  ... 106837295.81 10337391164.52
# 35 São Paulo           91678473.48 148677526.82  ... 392946147.42 41396604304.13
# 41 Paraná              38266347.46  55384670.52  ... 140264608.52 14681514706.67
# 42 Santa Catarina      16504913.45  25651429.11  ...  81376630.57  7835011163.40
# 43 Rio Grande do Sul   30931325.46  57363420.01  ... 130155185.16 12764391179.92
# 50 Mato Grosso do Sul   5377392.11   7002472.61  ...  25168195.34  2324525096.33
# 51 Mato Grosso          4795299.01   8684882.23  ...  19611032.61  2180119781.15
# 52 Goiás               15310637.29  22258668.68  ...  45592686.49  4973573613.47
# 53 Distrito Federal     4745919.19   7632480.67  ...  31831917.45  2592422853.56
#
# [27 rows x 159 columns]

# %%
usaveis['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    9170787.53
# 12 Acre        3204998.88
# 13 Amazonas   15787896.78
# 14 Roraima     3788154.80
# 15 Pará       31179893.86
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2008/Jan      902416.00
# 2008/Fev     1497206.26
# 2008/Mar     1794028.48
# 2008/Abr     1730469.42
# 2008/Mai     1819443.92
#                ...
# 2020/Dez     3696997.31
# 2021/Jan     3715723.12
# 2021/Fev     3538427.92
# 2021/Mar     4077045.92
# Total      450048530.47
# Name: 12 Acre, Length: 159, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2008/Jan               1388528.39  902416.00  ... 15310637.29           4745919.19
# 2008/Fev               2931283.42 1497206.26  ... 22258668.68           7632480.67
# 2008/Mar               1541682.52 1794028.48  ... 21442515.75           9647203.26
# 2008/Abr               1525314.96 1730469.42  ... 20921212.45          11098732.99
# 2008/Mai               1645953.84 1819443.92  ... 21615970.67          12891719.72
#
# [5 rows x 27 columns]

# %%
usaveis = usaveis.drop("Total", axis = 1)

# %%
usaveis.T.plot(figsize= (10,6))
