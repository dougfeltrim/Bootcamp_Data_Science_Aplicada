# %% [markdown]
# <a href="https://colab.research.google.com/github/dougfeltrim/Bootcamp_Data_Science_Aplicada/blob/main/Bootcamp_Data_Science_Aplicada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("/content/A192126189_28_143_208_aula_02.csv", engine='python', encoding="utf-8", skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2021/Mar         Total
# 0          11 Rondônia        -  ...   4732441.04  9.964113e+08
# 1              12 Acre        -  ...   1137341.65  4.500485e+08
# 2          13 Amazonas        -  ...   6799060.80  1.917248e+09
# 3           14 Roraima        -  ...   2381844.31  3.288770e+08
# 4              15 Pará        -  ...  13069564.31  4.705309e+09
#
# [5 rows x 287 columns]

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Dez    5.377291e+07
# 2021/Jan    4.947411e+07
# 2021/Fev    3.899242e+07
# 2021/Mar    2.416371e+07
# Total       6.388206e+09
# Length: 165, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 287 entries, Unidade da Federação to Total
# dtypes: float64(165), object(122)
# memory usage: 60.7+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 26641365.101481482

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x='Unidade da Federação' , y='2008/Ago', kind='bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Custo Hospitalar no Brasil em Agosto de 2008")

plt.show()

# %%
ax = dados.plot(x='Unidade da Federação' , y='2021/Mar', kind='bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Custo Hospitalar no Brasil em Março de 2021")

plt.show()

# %%
diferenca = dados['2021/Mar'].mean() - dados['2008/Ago'].mean()
print('%.2f' %  diferenca)
# Out:
# -2477652.22

# %%
dados[['2008/Mar','2021/Mar']]
# Out:
#        2008/Mar     2021/Mar
# 0    1955721.68   4732441.04
# 1    2057439.02   1137341.65
# 2    8641517.13   6799060.80
# 3     876091.18   2381844.31
# 4   22149375.82  13069564.31
# 5    1177745.93    989155.40
# 6    5200151.87    928756.84
# 7   14750895.33  17294509.11
# 8   10428191.09   9542151.53
# 9   30085370.22  17173151.55
# 10  10126626.54   8733455.36
# 11  12348758.14  12517894.05
# 12  30716361.81  39472738.81
# 13   9210505.56   8180887.21
# 14   5017838.07   3081081.42
# 15  41316672.72  31314602.44
# 16  79119005.51  79780838.00
# 17  12262049.08  15606368.11
# 18  42900847.02  49149884.48
# 19 170556696.16 177408317.71
# 20  55611791.07  43480729.07
# 21  27483480.50  19375822.56
# 22  52928695.92  37798832.80
# 23   9793888.78   4035989.77
# 24   9416367.68   8835890.09
# 25  20992213.03  24867001.02
# 26  11627918.26  14731938.43

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, 'Unidade da Federação')

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Mar         Total
# 0          11 Rondônia   4209.37  ...  4732441.04  996411254.68
# 1              12 Acre  10470.07  ...  1137341.65  450048530.47
# 2          13 Amazonas  35752.72  ...  6799060.80 1917247936.05
# 3           14 Roraima   4785.91  ...  2381844.31  328876965.09
# 4              15 Pará 181159.29  ... 13069564.31 4705309002.29
#
# [5 rows x 166 columns]

# %%
usaveis = usaveis.set_index(['Unidade da Federação'])

usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996411254.68
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450048530.47
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917247936.05
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876965.09
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705309002.29
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309860092.59
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1020028272.64
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871069498.04
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280888802.74
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591836650.18
# ...

# %%
usaveis['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis = usaveis.drop("Total", axis = 1)

# %%
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
ax = usaveis.T.plot(figsize= (10,7.5))
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Custo Hospitalar do SUS no Brasil ")
# Out:
# Text(0.5, 1.0, 'Custo Hospitalar do SUS no Brasil ')

# %%
usaveis2 = usaveis.T.head()
# usaveis2.columns
cinco_estados = usaveis2[["31 Minas Gerais","35 São Paulo", "32 Espírito Santo", "33 Rio de Janeiro", "12 Acre"]]

# %%
ax = cinco_estados.plot(kind = "bar", figsize= (10,10))
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Custo do SUS - Sudeste x Acre")
# Out:
# Text(0.5, 1.0, 'Custo do SUS - Sudeste x Acre')

# %%
usaveis['Total'] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Mar         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  4732441.04  996410650.35
# 12 Acre               10470.07  14001.71  ...  1137341.65  450047246.65
# 13 Amazonas           35752.72  45570.64  ...  6799060.80 1917245104.64
# 14 Roraima             4785.91  11858.63  ...  2381844.31  328876551.40
# 15 Pará              181159.29 433414.74  ... 13069564.31 4705290466.69
#
# [5 rows x 165 columns]

# %%
ordenado_por_total = usaveis.sort_values('Total', ascending=False)
ordenado_por_total = ordenado_por_total.drop("Total", axis=1)

ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 268193064.06 177408317.71
# 31 Minas Gerais       971394.37 2861781.50  ... 119877417.15  79780838.00
# 41 Paraná             554800.22 1431708.01  ...  83130175.37  43480729.07
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  84404640.00  37798832.80
# 33 Rio de Janeiro     469469.34  921646.57  ...  60873103.08  49149884.48
#
# [5 rows x 164 columns]

# %%
ordenado_por_total = ordenado_por_total.head()


ax = ordenado_por_total.T.plot(figsize=(10,6))
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("5 Estados com maiores gastos do SUS ")
# Out:
# Text(0.5, 1.0, '5 Estados com maiores gastos do SUS ')

# %%
colunas_interessadas = ordenado_por_total.columns[6:]

ordenado_por_total = ordenado_por_total[colunas_interessadas].head()

# %%
 ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
# sudeste =  usaveis.T[["31 Minas Gerais","35 São Paulo", "32 Espírito Santo", "33 Rio de Janeiro"]]
# sudeste.plot(figsize=(10,6))


# # ordenado_por_total = usaveis[colunas_interessadas]

# # ax = ordenado_por_total.plot(figsize=(10,6))
# # plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# # ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

# # plt.title("Comparando gastos do SUS entre Sudeste x Acre")

# %%
estados = usaveis.T.columns



numeros = []
num = []

norte = []
nordeste = []
sudeste = [] 
sul = []
centro = []
# separando as regioes do Brasil
for i in estados:
  num = int(i.split()[0])
  numeros.append(int(num))
  # print(i.split()[0])
  # print(num)
  if num >= 11 and num <= 17:
    print('Norte')
    print(i)
    norte.append(i)
  elif num >= 21 and num <= 29:
    print('Nordeste')
    print(i)
    nordeste.append(i)
  elif num >= 31 and num <= 35:
    print('Sudeste')
    print(i)
    sudeste.append(i)
  elif num >= 41 and num <= 43:
    print('Sul')
    print(i)
    sul.append(i)
  elif num >= 50 and num <= 53:
    print('Centro Oeste')
    print(i)
    centro.append(i)
# Out:
# Norte
# 11 Rondônia
# Norte
# 12 Acre
# Norte
# 13 Amazonas
# Norte
# 14 Roraima
# Norte
# 15 Pará
# Norte
# 16 Amapá
# Norte
# 17 Tocantins
# Nordeste
# 21 Maranhão
# Nordeste
# 22 Piauí
# Nordeste
# 23 Ceará
# Nordeste
# 24 Rio Grande do Norte
# Nordeste
# 25 Paraíba
# Nordeste
# 26 Pernambuco
# Nordeste
# 27 Alagoas
# Nordeste
# 28 Sergipe
# Nordeste
# 29 Bahia
# Sudeste
# 31 Minas Gerais
# Sudeste
# 32 Espírito Santo
# Sudeste
# 33 Rio de Janeiro
# Sudeste
# 35 São Paulo
# Sul
# 41 Paraná
# Sul
# 42 Santa Catarina
# Sul
# 43 Rio Grande do Sul
# Centro Oeste
# 50 Mato Grosso do Sul
# Centro Oeste
# 51 Mato Grosso
# Centro Oeste
# 52 Goiás
# Centro Oeste
# 53 Distrito Federal

# %%
usaveis['Regioes'] = 'NaN'
# adicionando a coluna de regioes
print(nordeste)
# Out:
# ['21 Maranhão', '22 Piauí', '23 Ceará', '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas', '28 Sergipe', '29 Bahia']

# %%
ordenado_por_total = ordenado_por_total / 1000000

# %%
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0,400)
# Out:
# (0.0, 400.0)

# %%
mes_mais_recente = ordenado_por_total.columns[-1]
mes_mais_recente
# Out:
# '2021/Mar'

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]

# %%
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           177.41
# 31 Minas Gerais         79.78
# 41 Paraná               43.48
# 43 Rio Grande do Sul    37.80
# 33 Rio de Janeiro       49.15
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente.plot(kind='pie')

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc['33 Rio de Janeiro']
# Out:
# Unidade da Federação
# 35 São Paulo           3.61
# 31 Minas Gerais        1.62
# 41 Paraná              0.88
# 43 Rio Grande do Sul   0.77
# 33 Rio de Janeiro      1.00
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar', grid='bool')
